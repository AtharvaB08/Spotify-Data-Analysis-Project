# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('SpotifyFeatures.csv')
df_tracks.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
df_tracks.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %%
df_tracks.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df_artist = pd.read_csv('artists.csv')
df_artist.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
df_artist.isnull().sum()
# Out:
# id             0
# followers     13
# genres         0
# name           0
# popularity     0
# dtype: int64

# %%
df_artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104349 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB

# %%
max_followers = df_artist['name']max(df_artist['followers'])
# Out:
#   File "C:\Users\hp\AppData\Local\Temp\ipykernel_1056\3827087863.py", line 1
#     max_followers = df_artist['name']max(df_artist['followers'])
#                                      ^
# SyntaxError: invalid syntax

# %%
max_followers
# Out:
# 'Ed Sheeran'

# %%
max_followers = df_artist.loc[df_artist['followers'].idxmax(), 'name']

# %%
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)

# %%
sorted_df
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# ...

# %%
max_followers = df_artist.sort_values('followers', ascending=False).head(1)

# %%
max_followers
# Out:
#                             id   followers             genres        name  \
# 144138  6eUKZXaKkcviH0Ku9w2n3V  78900234.0  ['pop', 'uk pop']  Ed Sheeran
#
#         popularity
# 144138          92

# %%
more_90 = df_tracks[df_tracks['popularity'] > 90]

# %%
more_90
# Out:
#             genre          artist_name  \
# 9026        Dance        Ariana Grande
# 9027        Dance        Ariana Grande
# 9028        Dance               Halsey
# 9029        Dance        Ariana Grande
# 9030        Dance        Ariana Grande
# ...           ...                  ...
# 138922  Reggaeton             Anuel Aa
# 138931  Reggaeton         Daddy Yankee
# 152266        R&B       Ellie Goulding
# 152287        R&B                Mabel
# 166057       Rock  Panic! At The Disco
#
#                                        track_name                track_id  \
# 9026     break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 9027                                      7 rings  14msK75pk3pA33pzPVNtBF
# 9028                                   Without Me  5p7ujcrUXASCNwRaWNHR1C
# 9029                                        needy  1TEL6MlSSVLSdhOSddidlJ
# 9030                                         NASA  4uTvPEr01pjTbZgl7jcKBD
# ...

# %%
most_popular = df_tracks.query('popularity>90', inplace= False).sort_values('popularity', ascending=False)
most_popular[:10]
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107802       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# ...

# %%
df_tracks[['artist_name']].iloc[18]
# Out:
# artist_name    Henri Salvador
# Name: 18, dtype: object

# %%
df_tracks['duration'] = df_tracks['duration_ms'].apply(lambda x: round(x/1000))
df_tracks.drop('duration_ms', inplace = True, axis = 1)

# %%
df_tracks.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
corr_df = df_tracks.drop(['key','mode'],axis = 1).corr(method = 'pearson')
plt.figure(figsize = (14,6))
heatmap = sns.heatmap(corr_df, annot=True, fmt =' .1g', vmin = -1, vmax = 1, cmap='inferno', linecolor= 'Black')
heatmap.set_title('Correlation HeatMap between Variable')
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation = 90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'acousticness'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'energy'),
#  Text(4.5, 0, 'instrumentalness'),
#  Text(5.5, 0, 'liveness'),
#  Text(6.5, 0, 'loudness'),
#  Text(7.5, 0, 'speechiness'),
#  Text(8.5, 0, 'tempo'),
#  Text(9.5, 0, 'valence'),
#  Text(10.5, 0, 'duration')]

# %%
sample_df = df_tracks.sample(int(0.004*len(df_tracks)))

# %%
len(sample_df)
# Out:
# 930

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y = 'loudness', x = 'energy', color='c').set(title = 'Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y = 'popularity', x = 'acousticness', color='g').set(title = 'Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %%
# !pip install --user seaborn==0.11.0

# %%
total_dr = df_tracks.duration
fig_dims = (18,7)
fig, ax = plt.subplots(figsize = fig_dims)
fig = sns.barplot(x = df_tracks['time_signature'], y = total_dr, ax = ax, errwidth = False).set(title = 'Year vs Duration')

# %%
total_dr = df_tracks.duration
fig_dims = (18,7)
fig, ax = plt.subplots(figsize = fig_dims)
fig = sns.lineplot(x = df_tracks['time_signature'], y = total_dr, ax = ax).set(title = 'Year vs Duration')

# %%
df_artist.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
df_artist['genres'].values
# Out:
# array(['[]', '[]', '[]', ..., '[]', '[]', '[]'], dtype=object)

# %%
sns.set_style(style = 'darkgrid')
plt.figure(figsize=(10,5))
famous = df_artist.sort_values('popularity', ascending=False).head(10)
sns.barplot(y= 'genres', x = 'popularity',data = famous).set(title= 'Top 10 Genres by Popularity')
# Out:
# [Text(0.5, 1.0, 'Top 10 Genres by Popularity')]
